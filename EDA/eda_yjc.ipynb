# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.cluster import KMeans


os.getcwd()
# Out:
# '/Users/yojeremijenko-conel/Dropbox/Mac (3)/Documents/ocean-depth-characterization/EDA'

# %%
PROFILE_DATA_PATH = "../../DSI_bgcArgoProject/data/profileData.csv"
SAT_DATA_PATH = "../../DSI_bgcArgoProject/data/satData.csv"

profile_df = pd.read_csv(PROFILE_DATA_PATH)
sat_df = pd.read_csv(SAT_DATA_PATH)

# %%
profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37469410 entries, 0 to 37469409
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   float        int64
#  1   cycleNumber  int64
#  2   date         object
#  3   PRES         int64
#  4   PSAL         float64
#  5   TEMP         float64
#  6   BBP700       float64
#  7   CHLA         float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 2.2+ GB

# %%
sat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66271 entries, 0 to 66270
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   float           66271 non-null  int64
#  1   cycleNumber     66271 non-null  int64
#  2   date            66271 non-null  object
#  3   latitude        66271 non-null  float64
#  4   longitude       66271 non-null  float64
#  5   elevation       66271 non-null  float64
#  6   MO_SAT_SST      62358 non-null  float64
#  7   MO_SAT_CHL      52921 non-null  float64
#  8   MO_SAT_BBP      52760 non-null  float64
#  9   LT_SAT_SST_SD   62993 non-null  float64
#  10  LT_SAT_SST_MED  62994 non-null  float64
#  11  LT_SAT_CHL_SD   66267 non-null  float64
#  12  LT_SAT_CHL_MED  62991 non-null  float64
#  13  LT_SAT_BBP_SD   62990 non-null  float64
#  14  LT_SAT_BBP_MED  62991 non-null  float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 7.6+ MB

# %%
float_ids = np.unique(profile_df.float)
num_floats = len(float_ids)
print(f"Total number of floats with proper sensors: {num_floats}")
# Out:
# Total number of floats with proper sensors: 569

# %%
float = profile_df[profile_df.float == np.random.choice(float_ids)]
for i in range(5):
    plt.scatter(float[float.cycleNumber == i].PRES, float[float.cycleNumber == i].BBP700, marker=".")
plt.legend([f"Cycle {i+1}" for i in range(5)])
plt.title("Sample of backscattering in float {}".format(float_ids[0]))
plt.show()

# %%
cycle1 = profile_df[profile_df.cycleNumber == 1]

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
float_ls = np.random.choice(float_ids, size=5)
for rand_float in float_ls:
    ax[0].scatter(cycle1[cycle1.float == rand_float].PRES, cycle1[cycle1.float == rand_float].BBP700, marker=".")
    ax[1].scatter(cycle1[cycle1.float == rand_float].PRES, cycle1[cycle1.float == rand_float].CHLA, marker=".")
ax[0].legend([f"Float {f}" for f in float_ls])
ax[0].set_title("Backscattering during cycle 1 on various floats")
ax[1].set_title("Chlorophyll a content during the same cycle")
plt.show()

# %%
sat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66271 entries, 0 to 66270
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   float           66271 non-null  int64
#  1   cycleNumber     66271 non-null  int64
#  2   date            66271 non-null  object
#  3   latitude        66271 non-null  float64
#  4   longitude       66271 non-null  float64
#  5   elevation       66271 non-null  float64
#  6   MO_SAT_SST      62358 non-null  float64
#  7   MO_SAT_CHL      52921 non-null  float64
#  8   MO_SAT_BBP      52760 non-null  float64
#  9   LT_SAT_SST_SD   62993 non-null  float64
#  10  LT_SAT_SST_MED  62994 non-null  float64
#  11  LT_SAT_CHL_SD   66267 non-null  float64
#  12  LT_SAT_CHL_MED  62991 non-null  float64
#  13  LT_SAT_BBP_SD   62990 non-null  float64
#  14  LT_SAT_BBP_MED  62991 non-null  float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 7.6+ MB

# %%
# Aggregate profile data using the mean value of chlorophyll a and bbp700 nm in the sunlit portion of the ocean
sunlit_profiles = profile_df[profile_df.PRES < 151][['float', 'cycleNumber', 'CHLA', 'BBP700']] \
    .groupby(['float', 'cycleNumber']).mean().reset_index()
df = sat_df.merge(sunlit_profiles, on=['float', 'cycleNumber']).drop(['LT_SAT_SST_SD', 'LT_SAT_SST_MED'], axis=1).dropna()

# %%
df.corr(method="spearman").style.background_gradient()
# Out:
# <style type="text/css">
# #T_68f81_row0_col0, #T_68f81_row1_col1, #T_68f81_row2_col2, #T_68f81_row3_col3, #T_68f81_row4_col4, #T_68f81_row5_col5, #T_68f81_row6_col6, #T_68f81_row7_col7, #T_68f81_row8_col8, #T_68f81_row9_col9, #T_68f81_row10_col10, #T_68f81_row11_col11, #T_68f81_row12_col12, #T_68f81_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col1, #T_68f81_row3_col0, #T_68f81_row10_col1, #T_68f81_row12_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_68f81_row0_col2, #T_68f81_row2_col6, #T_68f81_row6_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col3, #T_68f81_row5_col0, #T_68f81_row5_col4, #T_68f81_row5_col6, #T_68f81_row5_col7, #T_68f81_row5_col8, #T_68f81_row5_col9, #T_68f81_row5_col10, #T_68f81_row5_col11, #T_68f81_row5_col12, #T_68f81_row5_col13, #T_68f81_row10_col5, #T_68f81_row11_col2, #T_68f81_row13_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_68f81_row0_col4, #T_68f81_row2_col8, #T_68f81_row2_col9 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col5, #T_68f81_row1_col13, #T_68f81_row3_col7 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_68f81_row0_col6, #T_68f81_row4_col12 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col7 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_68f81_row0_col8 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col9 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_68f81_row0_col10, #T_68f81_row3_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_68f81_row0_col11, #T_68f81_row4_col11 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_68f81_row0_col12 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_68f81_row0_col13 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_68f81_row1_col0, #T_68f81_row9_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_68f81_row1_col2, #T_68f81_row6_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_68f81_row1_col3, #T_68f81_row10_col3, #T_68f81_row13_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_68f81_row1_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_68f81_row1_col5, #T_68f81_row2_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_68f81_row1_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_68f81_row1_col7 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_68f81_row1_col8, #T_68f81_row4_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_68f81_row1_col9 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_68f81_row1_col10, #T_68f81_row3_col8, #T_68f81_row9_col2 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_68f81_row1_col11 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_68f81_row1_col12 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_68f81_row2_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_68f81_row2_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_68f81_row2_col3, #T_68f81_row11_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_68f81_row2_col5 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_68f81_row2_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_68f81_row2_col10, #T_68f81_row10_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_68f81_row2_col11 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_68f81_row2_col12 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_68f81_row2_col13, #T_68f81_row7_col4 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_68f81_row3_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_68f81_row3_col2, #T_68f81_row7_col0, #T_68f81_row10_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_68f81_row3_col4, #T_68f81_row13_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_68f81_row3_col6, #T_68f81_row3_col9, #T_68f81_row3_col11 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_68f81_row3_col10 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_68f81_row3_col12 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_68f81_row3_col13 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_68f81_row4_col0 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_68f81_row4_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col3, #T_68f81_row11_col4 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_68f81_row4_col5 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_68f81_row4_col6 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col8 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col9 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col10 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_68f81_row4_col13 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_68f81_row5_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_68f81_row5_col2, #T_68f81_row8_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_68f81_row5_col3, #T_68f81_row7_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_68f81_row6_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_68f81_row6_col2 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_68f81_row6_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_68f81_row6_col5, #T_68f81_row11_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_68f81_row6_col7 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col8, #T_68f81_row8_col10 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col9, #T_68f81_row9_col6 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col11 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col12, #T_68f81_row10_col13, #T_68f81_row12_col6 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_68f81_row6_col13, #T_68f81_row13_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col1, #T_68f81_row11_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_68f81_row7_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_68f81_row7_col5, #T_68f81_row10_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_68f81_row7_col6 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col8 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col9 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col10, #T_68f81_row9_col13, #T_68f81_row12_col7 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col11, #T_68f81_row11_col12 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col12 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_68f81_row7_col13, #T_68f81_row9_col11, #T_68f81_row13_col11 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col0, #T_68f81_row9_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_68f81_row8_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_68f81_row8_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_68f81_row8_col4 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col5, #T_68f81_row13_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_68f81_row8_col6 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col7 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col9, #T_68f81_row9_col8 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col11 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col12 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_68f81_row8_col13, #T_68f81_row13_col8 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_68f81_row9_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_68f81_row9_col4 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_68f81_row9_col5, #T_68f81_row12_col5, #T_68f81_row13_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_68f81_row9_col7 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_68f81_row

# %%
Xc = df[["latitude", "MO_SAT_CHL", "LT_SAT_CHL_MED"]]
yc = df["CHLA"]
Xb = df[["latitude", "MO_SAT_BBP", "LT_SAT_BBP_MED"]]
yb = df["BBP700"]

rclf_c = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1], cv=5, scoring='neg_mean_squared_error').fit(Xc, yc)
print("Initial score for ridgereg [CHLA]: {}".format(rclf_c.score(Xc, yc)))

rclf_b = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1], cv=5, scoring='neg_mean_squared_error').fit(Xb, yb)
print("Initial score for ridgereg [BBP700]: {}".format(rclf_b.score(Xb, yb)))
# Out:
# Initial score for ridgereg [CHLA]: 0.36016952453696793
# Initial score for ridgereg [BBP700]: 0.004898620373892992

# %% [markdown]
# ### Questions / Comments on Neural Net Paper
#
# 1. How are the input values giving four "potential density values along the vertical profile" derived? (aren't those theoretically very similar to the output values we are trying to achieve? Are they using some aggregation of past float values based on time / location?)
#
# 2. Clarification on the use of Z_norm values and their relationship to attenuation coefficients at very specific wavelengths. Further clarification on the lack of similarity between Z_norm calculation between stratified and mixed water columns. (How are they finding this "statistical optimality")
#
# 3. What pieces of the dataset we have in hand are similar to the data they calculated / used (what do we have and what else do we need to calculate to repeat / extend their work)

# %%
df['date_doy'] = df['date'].apply(lambda x: pd.Period(x, freq='D').day_of_year)
df['date_doy_rad'] = df['date_doy'] * (np.pi /182.625)
score = list()

# %%
Xc_boost = df[["latitude", "MO_SAT_CHL", "MO_SAT_BBP", "LT_SAT_CHL_MED", "date_doy_rad", "MO_SAT_SST"]]
# Xc_boost = df[["latitude", "MO_SAT_CHL", "LT_SAT_CHL_MED", "date_doy_rad"]]
# Xc_boost = df[["latitude", "MO_SAT_CHL", "date_doy_rad", "MO_SAT_SST"]]
yc_boost = df["CHLA"]

X_tr, X_te, y_tr, y_te = train_test_split(Xc_boost, yc_boost, test_size=0.15, random_state=23)

reg = GradientBoostingRegressor(loss="squared_error", random_state=23)
hist = reg.fit(X_tr, y_tr)
score1 = reg.score(X_te, y_te)

score.append(score1)
print(score)
# Out:
# [0.581367811391156]

# %%
Xc_boost.shape
# Out:
# (48620, 6)

# %%
preds = reg.predict(X_te)
mae = mean_absolute_error(y_te, preds)
print(f"Mean absolute error: {mae}")
print(f"Mean pred value: {np.mean(preds)}")
print(f"Std. of preds: {np.std(preds)}")
print(f"Mean label value: {np.mean(y_te)}")
print(f"Std. of labels: {np.std(y_te)}")
print(f"Range of labels: {np.min(y_te)}, {np.max(y_te)}")
# Out:
# Mean absolute error: 0.09222631398451399
# Mean pred value: 0.2828321079431807
# Std. of preds: 0.21399408938332884
# Mean label value: 0.27842482497869875
# Std. of labels: 0.26812646490390013
# Range of labels: -0.02817023744102982, 4.841698022863519

# %% [markdown]
# Z_norm. Depth where phytoplankton cant grow
# Z_m = mixed layer depth
# Z_e = euphotic zone depth
#
# Ideas:
#
# more profiles are available, so we may need to rely less on past float data
#
# Needs:
#
# figure out what other data we can get from the satellites to use as features

# %%
# importing the libraries
from keras.models import Sequential
from keras.layers import Dense

# create ANN model
model = Sequential()

# Defining the Input layer and FIRST hidden layer, both are same!
model.add(Dense(units=6, input_dim=6, kernel_initializer='normal', activation='relu'))

# Defining the Second layer of the model
# after the first layer we don't have to specify input_dim as keras configure it automatically
model.add(Dense(units=18, kernel_initializer='normal', activation='relu'))

# The output neuron is a single fully connected node 
# Since we will be predicting a single number
model.add(Dense(1, kernel_initializer='normal'))

# Compiling the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Fitting the ANN to the Training set
model.fit(X_tr, y_tr ,batch_size = 64, epochs = 35, verbose=1)
# Out:
# Epoch 1/35
# 2022-10-04 15:27:32.081163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0798
# Epoch 2/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0609
# Epoch 3/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0570
# Epoch 4/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0512
# Epoch 5/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0490
# Epoch 6/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0482
# Epoch 7/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0476
# Epoch 8/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0473
# Epoch 9/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0470
# Epoch 10/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0466
# Epoch 11/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0462
# Epoch 12/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0457
# Epoch 13/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0454
# Epoch 14/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0451
# Epoch 15/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0448
# Epoch 16/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0447
# Epoch 17/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0443
# Epoch 18/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0441
# Epoch 19/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0438
# Epoch 20/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0438
# Epoch 21/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0436
# Epoch 22/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0435
# Epoch 23/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0433
# Epoch 24/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0431
# Epoch 25/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0431
# Epoch 26/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0430
# Epoch 27/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0427
# Epoch 28/35
# 323/323 [==============================] - 1s 5ms/step - loss: 0.0426
# Epoch 29/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0424
# Epoch 30/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0423
# Epoch 31/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0421
# Epoch 32/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0419
# Epoch 33/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0420
# Epoch 34/35
# 323/323 [==============================] - 1s 4ms/step - loss: 0.0417
# Epoch 35/35
# 323/323 [==============================] - 2s 5ms/step - loss: 0.0416

# %%
# Defining a function to find the best parameters for ANN
def FunctionFindBestParams(X_train, y_train, X_test, y_test):
    
    # Defining the list of hyper parameters to try
    batch_size_list=[32, 64, 128, 256]
    epoch_list  =   [ 10, 15, 25, 35]
    
    SearchResultsData=pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
    
    # initializing the trials
    TrialNumber=0
    for batch_size_trial in batch_size_list:
        for epochs_trial in epoch_list:
            TrialNumber+=1
            # create ANN model
            model = Sequential()
            # Defining the first layer of the model
            model.add(Dense(units=6, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

            # Defining the Second layer of the model
            model.add(Dense(units=6, kernel_initializer='normal', activation='relu'))

            # The output neuron is a single fully connected node 
            # Since we will be predicting a single number
            model.add(Dense(1, kernel_initializer='normal'))

            # Compiling the model
            model.compile(loss='mean_squared_error', optimizer='adam')

            # Fitting the ANN to the Training set
            model.fit(X_train, y_train ,batch_size = batch_size_trial, epochs = epochs_trial, verbose=0)

            MAPE = np.mean(100 * (np.abs(np.array(y_test)-model.predict(X_test))/np.array(y_test)))
            
            # printing the results of the current iteration
            print(TrialNumber, 'Parameters:','batch_size:', batch_size_trial,'-', 'epochs:',epochs_trial, 'Accuracy:', 100-MAPE)
            
            SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber, str(batch_size_trial)+'-'+str(epochs_trial), 100-MAPE]],
                                                                    columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
    return(SearchResultsData)

# %%
# %%time
######################################################
# Calling the function
ResultsData=FunctionFindBestParams(X_tr, y_tr, X_te, y_te)
# Out:
# 2022-10-04 15:35:23.849748: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-10-04 15:36:09.851952: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 1 Parameters: batch_size: 32 - epochs: 10 Accuracy: -48.795387666648594
# 2022-10-04 15:36:10.761031: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-10-04 15:37:22.152519: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2 Parameters: batch_size: 32 - epochs: 15 Accuracy: -49.48450372862959
# 2022-10-04 15:37:23.234419: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-10-04 15:50:14.710698: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 3 Parameters: batch_size: 32 - epochs: 25 Accuracy: -61.16000964563682
# 2022-10-04 15:51:11.979517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
y_pred = model.predict(X_te)

# %%
from sklearn.metrics import r2_score
r2_score(y_te, y_pred)

# %%
metric = tf.metrics.r_square.RSquare()
metric.update_state(y_true, y_pred)
result = metric.result()
result.numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2s/dqvyr8r92_v2nfvgky0vvxbc0000gn/T/ipykernel_8615/433313009.py in <module>
# ----> 1 metric = tf.metrics.r_square.RSquare()
#       2 metric.update_state(y_true, y_pred)
#       3 result = metric.result()
#       4 result.numpy()
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ### Check average distance between two date recordings

# %%
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M:%S')

# %%
deltas = list()
for f in np.unique(df.float):
    float_df = df[df.float == f].sort_values(by='date', ascending=True)
    float_df['delta'] = (float_df['date'] - float_df['date'].shift()).fillna(pd.Timedelta('0 days'))
    float_df['delta_hrs'] = float_df['delta'].apply(lambda x: x / np.timedelta64(1, 'D')).astype('float')
    deltas += list(float_df['delta_hrs'])

# %%
deltas = np.array(deltas)
deltas_filt = deltas[(deltas < 15) & (deltas > 0)]

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
sns.histplot(x=deltas_filt, ax=ax)
ax.set_xlabel('Days between cycle measurements')
plt.show()

# %%
est = KMeans(n_clusters=6)
groups = est.fit_predict(df[['BBP700', "CHLA"]])

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.scatter(df.BBP700.to_list(), df.CHLA.to_list(), c=groups)
plt.show()
